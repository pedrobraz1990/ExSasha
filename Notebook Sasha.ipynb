# %% [markdown]
# Sasha eu não sei a sintaxe do C de cabeça , vou escrever em python (que é uma sintaxe genérica) e vc passa pra C, pode ser ?
#
#
# Supondo que vc já pegou os dos inputs ``m`` e ``n``
#
# Você sabe que necessariamente cada cada linha vai ter ``m*n`` números e que voce vai ter que escrever ``m*n`` linhas. Correto ?
#
# Então você vai fazer um for para escrever as linhas e um para os vetores.
#
# Com estes dois for nós iremos escrever elemento por elemento (como vc disse que não pode usar matrizes). Então basta agente identificar se ele esta em um quadrado par ou impar.
#
#
# Existem infinitas maneiras de fazer a lógica para descobrir isto, mas uma delas é seguinte:
#
# Se você olhar só para uma linha: 1 1 0 0 1 1 0 0 ....
# * Os elementos 1 e 2 = 1
# * Os elementos 3 e 4 = 0
# * Os elementos 5 e 6 = 1
#
# Percebe que se voce dividir os elementos por dois fica:
# * Os elementos 0.5 e 1 = 1
# * Os elementos 1.5 e 2 = 0
# * Os elementos 2.5 e 3 = 1
#
# Percebe que o primeiro elemento é fracionário e o segundo é inteiro ? uma possível lógica então é :
#  se eu estou escrevendo o i-ésimo elemento ele será:
#
#  $$
# n_i =
# \left\{
# 	\begin{array}{ll}
# 		n_{i-1}  & \mbox{if } i  mod 1 == 0 \\
# 		oposto & \mbox{if } i  mod 1 \neq 0
# 	\end{array}
# \right.
# $$
#
# Acho que vc já aprendeu o operador ``mod`` certo ? ``i mod 1`` significa o resto da divisão de ``i`` por ``1`` . Um exemplo é ``2.7 mod 1 = 0.7 ``.
#
#
# Com isto só falta descobrirmos qual o primeiro elemento da linha. se ele é zero ou um. Podemos usar a mesma lógica, afinal:
# * As linhas 1 e 2 começam com 1
# * As linhas 3 e 4 começam com 0
# * As linhas 5 e 6 começam com 1
#
# então , se estamos escrevendo a j-ésima linha:
#  $$
# l_j =
# \left\{
# 	\begin{array}{ll}
# 		l_{j-1}  & \mbox{if } i  mod 1 == 0 \\
# 		oposto & \mbox{if } i  mod 1 \neq 0
# 	\end{array}
# \right.
# $$

# %% [markdown]
# Sasha eu não sei a sintaxe do C de cabeça , vou escrever em python (que é uma sintaxe genérica) e vc passa pra C, pode ser ?
#
#
# Supondo que vc já pegou os dos inputs ``m`` e ``n``
#
# Você sabe que necessariamente cada cada linha vai ter ``m*n`` números e que voce vai ter que escrever ``m*n`` linhas.
#
# Então você vai fazer um ``for`` para escrever as linhas e um para os vetores.
#
# Com estes dois ``for`` nós iremos escrever elemento por elemento (como vc disse que não pode usar matrizes).
#
# Nós precisamos de um contador que nos avise quando já escrevemos 1 ou 0 ``m`` vezes. Desta forma vai bastar saber com qual número a linha começa
#
#
#
# Existem infinitas maneiras de fazer a lógica para descobrir isto, mas uma delas é seguinte:

# %%
m = 2
n = 3



# A variavel proximoNumero sempre vai guardar o proximo numero que vamos escrever 

if -1^n <0:
# se n eh impar
    proximoNumero = 1
else:
# se n eh par    
    proximoNumero = 1

    
    
    
# Agora precisamos dos nossos contadores horizontal e vertical   
contHorizontal = 0
contVertical = 0

for numeroColuna in range(1,m*n):
# indo de 1 ate m*n

# vamos criar uma variavel linha para colocar todos os elementos e imprimir
linha = ''

    for numeroLinha in range(1,m*n):
    # indo de 1 ate m*n
